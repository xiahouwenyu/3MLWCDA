# %%
import matplotlib, sys,  os
import numpy as np
matplotlib.use('Agg')
import matplotlib.pyplot as plt

from tqdm import tqdm

import healpy as hp
import sys
import os
sys.path.append("/data/home/cwy/Science/3MLWCDA/Standard/src/")
import mylib as my
from importlib import reload
# Out:
# Load Mymodels:   5%|▌         | 2/38 [00:00<00:03,  9.30it/s]
# Welcome to JupyROOT 6.24/06
# 13:52:51 WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=172299;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=860381;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
# Load Mymap:  11%|█         | 4/38 [00:39<09:24, 16.60s/it]     /data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/numpy/lib/npyio.py:2313: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)
# 13:52:53 INFO      Starting 3ML!                                                                     ]8;id=444285;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=569993;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=662199;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=575613;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=673241;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=24015;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=597400;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=164162;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
# 13:52:55 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=448027;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=247453;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=164991;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=290669;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=79459;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=144822;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 13:52:55 WARNING   No fermitools installed                                              ]8;id=376083;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=675567;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=146283;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=127999;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=505442;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=954866;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=433572;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=849870;file:///data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
# Load Myfit:  13%|█▎        | 5/38 [00:42<04:31,  8.24s/it]
# WARNING NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "process_dec_bins" failed type inference due to: Use of unsupported NumPy function 'numpy.einsum' or unsupported use of the function.
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 39:
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
#     ss1_sum = np.einsum('ij,j->i', sflux, ss1) * w1
#     ^
#
# During: typing of get attribute at /data/home/cwy/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py (39)
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 39:
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
#     ss1_sum = np.einsum('ij,j->i', sflux, ss1) * w1
#     ^
#
#
#
# WARNING NumbaWarning: Function "process_dec_bins" was compiled in object mode without forceobj=True.
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 38:
# @jit(["float64[:](float64[:,:], float64[:], float64[:], float64[:], float64[:])"], parallel=False)
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
# ^
#
#
#
# WARNING NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../../../../../.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py", line 38:
# @jit(["float64[:](float64[:,:], float64[:], float64[:], float64[:], float64[:])"], parallel=False)
# def process_dec_bins(sflux, w1, w2, ss1, ss2):
# ^
#
#
# ReLoad Mycatalog:  61%|██████    | 23/38 [00:44<01:38,  6.58s/it]
# WARNING VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# Load sub from Mystat: : 40it [00:44,  1.23it/s]
# Yourlib init successfully!!!

# %%
savename="WCDA_20240731_0-6_2.6_Flux"
nside=1024
npix=hp.nside2npix(nside)
skymap=np.zeros(npix)
for i in tqdm(range(768)):
    try:
        data=np.loadtxt(f"sig_no{i}.txt")
    except Exception as e:
        print(i, e)
        continue
    for j in range(len(data)):
        try:
            skymap[int(data[j][0])]=float(data[j][2])
        except Exception as e:
            print(i, e)
            continue
skymap=hp.ma(skymap)
# %matplotlib inline

my.hpDraw("region_name", "Modelname", skymap,0,0,skyrange=(0,360,-20,85),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename, dpi=300) #zmax=30, , zmax=80 , color="Milagro"
plt.savefig(f"fullsky_{savename}.pdf",dpi=300) #{ "TeVCat": [1, "s"], "size": 20,"markercolor": "grey","labelcolor": "grey","angle": 60,"catext": 0 }

nestid = hp.ring2nest(1024, np.arange(hp.nside2npix(1024)))
nestmap=np.zeros(hp.nside2npix(1024))
nestmap[nestid] = skymap
nestmap = hp.ma(nestmap)
hp.mollview(nestmap, nest=1)
hp.write_map(f"fullsky_{savename}.fits.gz",skymap,overwrite=True)
map2 = my.change_coord(skymap,["C","G"])
hp.write_map(f"fullsky_{savename}.fits",map2,overwrite=True)
# Out:
# 100%|██████████| 768/768 [01:30<00:00,  8.52it/s]
#
# WARNING UserWarning: Warning: converting a masked element to nan.
#
#
# WARNING UserWarning: No contour levels were found within the data range.
#
# setting the output map dtype to [dtype('float64')]
# setting the output map dtype to [dtype('float64')]

# %%
map2 =  hp.read_map(f"/data/home/cwy/Science/3MLWCDA/data/fullsky_WCDA_20240731_0-6_2.6.fits")

# %%
# %matplotlib inline
hp.mollview(map2, title="LHAASO full sky", xsize=2048, max=30)

# %%
reload(my)
# Out:
# Load sub from Mystat: : 40it [00:25,  1.55it/s]
# ReLoad Mycatalog:  61%|██████    | 23/38 [00:00<00:00, 181.82it/s]
# WARNING VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#
# Load sub from Mystat: : 40it [00:00, 181.82it/s]
# Yourlib init successfully!!!
# <module 'mylib' from '/data/home/cwy/Science/3MLWCDA/Standard/src/mylib/__init__.py'>

# %%
map2 = hp.ma(map2)
my.getsig1D(map2, "region_name", "Modelname", "fullsky_gal", bins=1000)
# Out:
# 13:52:36 INFO      ************************                                                         ]8;id=428100;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py\Mysigmap.py]8;;\:]8;id=834844;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py#650\650]8;;\
#          INFO      [1.64521081e+06 4.38889722e-02 1.03494227e+00]                                   ]8;id=348687;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py\Mysigmap.py]8;;\:]8;id=634200;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py#651\651]8;;\
#          INFO      ************************                                                         ]8;id=792041;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py\Mysigmap.py]8;;\:]8;id=863554;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py#652\652]8;;\
# 13:52:37 INFO      max Significance= 528.2                                                          ]8;id=993622;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py\Mysigmap.py]8;;\:]8;id=864559;file:///data/home/cwy/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py#653\653]8;;\
# WARNING SyntaxWarning: "is not" with a literal. Did you mean "!="?
#
#
# WARNING SyntaxWarning: "is not" with a literal. Did you mean "!="?
#
#
# WARNING SyntaxWarning: "is not" with a literal. Did you mean "!="?
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 map2 = hp.ma(map2)
# ----> 2 my.getsig1D(map2, "region_name", "Modelname", "fullsky_gal", bins=1000)
#
# File ~/Science/3MLWCDA/Standard/src/mylib/Mysigmap.py:680, in getsig1D(S, region_name, Modelname, name, showexp, logy, ylimsclae, xlimscale, bins)
#     678 plt.ylabel("entries")
#     679 plt.legend()
# --> 680 plt.savefig(f"../res/{region_name}/{Modelname}/hist_sig_{name}.pdf")
#     681 plt.savefig(f"../res/{region_name}/{Modelname}/hist_sig_{name}.png",dpi=300)
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/pyplot.py:954, in savefig(*args, **kwargs)
#     951 @_copy_docstring_and_deprecators(Figure.savefig)
#     952 def savefig(*args, **kwargs):
#     953     fig = gcf()
# --> 954     res = fig.savefig(*args, **kwargs)
#     955     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     956     return res
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
#    3270     for ax in self.axes:
#    3271         stack.enter_context(
#    3272             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3274 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:2808, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2806     file = filename._file
#    2807 else:
# -> 2808     file = PdfFile(filename, metadata=metadata)
#    2809 try:
#    2810     file.newPage(width, height)
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:713, in PdfFile.__init__(self, filename, metadata)
#     711 self.original_file_like = None
#     712 self.tell_base = 0
# --> 713 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     714 if not opened:
#     715     try:
#
# File ~/.mylib/miniconda3/envs/3ML/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:492, in to_filehandle(fname, flag, return_opened, encoding)
#     490         fh = bz2.BZ2File(fname, flag)
#     491     else:
# --> 492         fh = open(fname, flag, encoding=encoding)
#     493     opened = True
#     494 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../res/region_name/Modelname/hist_sig_fullsky_gal.pdf'
# Load sub from Mystat: : 40it [00:12, 181.82it/s]

# %%
np.ma.max(skymap)

# %%
ss2 = hp.sphtfunc.smoothing(skymap,sigma=np.radians(0.5))

# %%
mapg2 = my.change_coord(ss2,["C","G"])

# %%
my.hpDraw("region_name", "Modelname", mapg2,0,0,skyrange=(0,360,-90,90),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", mapg,0,0,skyrange=(0,360,-90,90),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", ss2,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", ss2,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
my.hpDraw("region_name", "Modelname", ss2,0,0,skyrange=(0,360,-20,80),
            colorlabel="Significance", contours=[1000], save=False, cat={}, color="Milagro", xsize=2048, plotmol=1, savename=savename) #zmax=30,

# %%
from scipy.optimize import curve_fit
def gaussian(x,a,mu,sigma):
    return a*np.exp(-((x-mu)/sigma)**2/2)
nside=2**10
npix=hp.nside2npix(nside)
pixarea = 4 * np.pi/npix


pixIdx = hp.nside2npix(nside) # number of pixels I can get from this nside
pixIdx = np.arange(pixIdx) # pixel index numbers
new_lats = 90-hp.pix2ang(nside, pixIdx)[0]*180/np.pi # thetas I need to populate with interpolated theta values
new_lons = hp.pix2ang(nside, pixIdx)[1]*180/np.pi # phis, same
mask = (new_lats>15 )  & (new_lats < 20 ) & (new_lons>250) * (new_lons<255)
ra_J0057, dec_J0057 =  14,63.5
ra1,dec1=ra_J0057, dec_J0057

# data_radius = 6.0
# S = skymap[mask]
# S = my.maskdiskout(skymap, ra1, dec1, 6)
S = map2
bin_y,bin_x,patches = plt.hist(S.compressed(),bins=1000)
plt.yscale("log")
plt.xlim(-10,10)
plt.close()
bin_x=np.array(bin_x)
bin_y=np.array(bin_y)
fit_range = np.logical_and(bin_x>-5, bin_x<5)
wdt=(bin_x[1]-bin_x[0])/2.
try:
    popt, pcov = curve_fit(
        gaussian,
        bin_x[fit_range] + wdt,
        bin_y[fit_range[:-1]],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
except (ValueError, IndexError):
    popt, pcov = curve_fit(
        gaussian,
        bin_x[:100] + wdt,
        bin_y[:100],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
#popt,pcov = curve_fit(gaussian,bin_x[fit_range[0:-1]]+(bin_x[1]-bin_x[0])/2.,bin_y[fit_range[0:-1]],bounds=([100,-2,0],[50000000,2,10]))
print("************************")
print(popt)
print("************************")
print("max Significance= %.1f"%(max(S.compressed())))

plt.figure()
#plt.plot([0.,0.],[1,1e6],'k--',linewidth=0.5)
plt.plot(
    (bin_x[:1000] + bin_x[1:1001]) / 2,
    gaussian((bin_x[:1000] + bin_x[1:1001]) / 2, popt[0], 0, 1),
    '--',
    label='expectation',
)
plt.plot((bin_x[:1000] + bin_x[1:1001]) / 2, bin_y, label="data")
plt.plot(
    (bin_x[:1000] + bin_x[1:1001]) / 2,
    gaussian((bin_x[:1000] + bin_x[1:1001]) / 2, popt[0], popt[1], popt[2]),
    '--',
    label='fit',
)
plt.yscale('log')
plt.xlim(-10,10)
plt.ylim(1,max(bin_y*2))
plt.grid(True)
plt.text(-9.5,max(bin_y),'mean = %f\n width = %f'%(popt[1],popt[2]))
plt.xlabel(r'Significance($\sigma$)')
plt.ylabel("entries")
plt.legend()
# Out:
# ************************
# [1.64521081e+06 4.38889722e-02 1.03494227e+00]
# ************************
# max Significance= 528.2
